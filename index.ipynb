# %% [markdown]
# # Guitar classifier
# Welcome to our guitar classifier!

# %%
import fastai
from fastai.vision.all import *
from fastai.vision.widgets import *
from fastdownload import download_url

learn_inf = load_learner("export.pkl")

def on_click_classify(change):
    # Load image that has been uploaded
    img = PILImage.create(btn_upload.data[-1])

    # Let's clear the previous output (if any)
    out_pl.clear_output()

    # Display the image
    with out_pl: 
      display(img.to_thumb(128,128))
    
    # Calling the model
    (pred, pred_idx, probs) = learn_inf.predict(img) 

    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

# Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

btn_run = widgets.Button(description='Classify')
btn_run.on_click(on_click_classify)

lbl_pred = widgets.Label()
# lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

out_pl = widgets.Output()
out_pl.clear_output()

VBox(
    [
     widgets.Label('Select your guitar!'), 
     btn_upload, 
     btn_run, 
     out_pl, 
     lbl_pred
     ]
     )

# %%
# def test():
#   img_url = "https://static.gibson.com/product-images/USA/USAQ17249/Faded%20Pelham%20Blue%20Top/front-banner-500_500.png"

#   dest = 'images/electric.png'
#   download_url(img_url, dest) 
#   print(f"The vocabulary is: {learn_inf.dls.vocab}")
#   img = PILImage.create(dest)
#   display(img)
#   results = learn_inf.predict('images/electric.png')
#   print(f"The result is: {results}")

# test()
